# %% [markdown]
# # Chart Styles

# %%
import matplotlib.pyplot as plt
from matplotlib import style
import numpy as np

y=np.array([35,25,25,15])
subjectlabel=["English","Maths","Science","Geography"]
plt.pie(y,labels=subjectlabel)
style.use('dark_background')
print(plt.style.available)
plt.show()
# Out:
# ['bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark-palette', 'seaborn-dark', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'seaborn', 'Solarize_Light2', 'tableau-colorblind10', '_classic_test']

# %%
import matplotlib.pyplot as plt
from matplotlib import style
import numpy as np

x=np.array([35,25,25,15])
food=["Pizza","Pasta","Cake","Chips"]
plt.pie(x,labels=food)
style.use('grayscale')
#print(plt.style.available)
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import style
import numpy as np

y=np.array([35,25,25,15])
subjectlabel=["English","Maths","Science","Geography"]
plt.pie(y,labels=subjectlabel)
style.use('seaborn-bright')
#print(plt.style.available)
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import style
import numpy as np

y=np.array([15,25,10,15,20,5,10])
items=["Education for Children","Food","Clothes","Savings","Others","Transport","House rent"]
plt.pie(y,labels=items)
style.use('grayscale')
#print(plt.style.available)
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import style
import numpy as np

y=np.array([20,40,30,10])
dance=["Semi Classical","Light","Folk","Classical"]
plt.pie(y,labels=dance)
#style.use('grayscale')
style.use('seaborn-bright')
#print(plt.style.available)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data to plot
labels = 'Python', 'C++', 'Ruby', 'Java'
sizes = [215, 130, 245, 210]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0.1, 0, 0, 0)  # explode 1st slice

# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.show()

# %% [markdown]
# # Time Series

# %%
from datetime import datetime
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('goldsilver.csv')
df = pd.DataFrame(data, columns = ['Date', 'Gold22k'])
# Set the Date as Index
df['Date'] = pd.to_datetime(df['Date'])
df.index = df['Date']
del df['Date']

df.plot(figsize=(15, 6))
plt.show()

# %%
import pandas as pd
pd.date_range('2015-07-03 11:00', periods=8)
# Out:
# DatetimeIndex(['2015-07-03 11:00:00', '2015-07-04 11:00:00',
#                '2015-07-05 11:00:00', '2015-07-06 11:00:00',
#                '2015-07-07 11:00:00', '2015-07-08 11:00:00',
#                '2015-07-09 11:00:00', '2015-07-10 11:00:00'],
#               dtype='datetime64[ns]', freq='D')

# %%
import pandas as pd
pd.date_range('2015-07-03 11:00', periods=8, freq='H')
# Out:
# DatetimeIndex(['2015-07-03 11:00:00', '2015-07-03 12:00:00',
#                '2015-07-03 13:00:00', '2015-07-03 14:00:00',
#                '2015-07-03 15:00:00', '2015-07-03 16:00:00',
#                '2015-07-03 17:00:00', '2015-07-03 18:00:00'],
#               dtype='datetime64[ns]', freq='H')

# %%
df=pd.read_csv("germanydaily.csv")
df = df.set_index('Date')
df.tail(3)
# Out:
#             Consumption     Wind   Solar  WindSolar  Year  Month   Weekday
# Date
# 2012-02-27     1436.095   86.956  43.099    130.055  2012      2     Monday
# 2012-02-28     1408.211  231.923  16.190    248.113  2012      2    Tuesday
# 2012-02-29     1434.062   77.024  30.360    107.384  2012      2  Wednesday

# %% [markdown]
# # Heatmaps

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# Create a dataset
df = pd.DataFrame(np.random.random((10,10)), columns=["a","b","c","d","e","f","g","h","i","j"])
# plot using a color palette
sns.heatmap(df)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# Create a dataset
df = pd.DataFrame(np.random.random((10,10)), columns=["a","b","c","d","e","f","g","h","i","j"])
# plot using a color palette
sns.heatmap(df, cmap="winter")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# Create a dataset
df = pd.DataFrame(np.random.random((10,10)), columns=["a","b","c","d","e","f","g","h","i","j"])
# plot using a color palette
sns.heatmap(df, cmap="summer")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# Create a dataset
df = pd.DataFrame(np.random.random((10,10)), columns=["a","b","c","d","e","f","g","h","i","j"])
# plot using a color palette
sns.heatmap(df, cmap="Greens")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# Create a dataset
df = pd.DataFrame(np.random.random((10,10)), columns=["a","b","c","d","e","f","g","h","i","j"])
# plot using a color palette
sns.heatmap(df, cmap="PiYG")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# Create a dataset
df = pd.DataFrame(np.random.random((10,10)), columns=["a","b","c","d","e","f","g","h","i","j"])
# plot using a color palette
sns.heatmap(df, cmap="Blues")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# Create a dataset
df = pd.DataFrame(np.random.random((10,10)), columns=["a","b","c","d","e","f","g","h","i","j"])
# plot using a color palette
sns.heatmap(df, cmap="coolwarm")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# Create a dataset
df = pd.DataFrame(np.random.random((10,10)), columns=["a","b","c","d","e","f","g","h","i","j"])
# plot using a color palette
sns.heatmap(df, cmap="cool")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# Create a dataset
df = pd.DataFrame(np.random.random((10,10)), columns=["a","b","c","d","e","f","g","h","i","j"])
# plot using a color palette
sns.heatmap(df, cmap="copper")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()
flights = sns.load_dataset("flights")
flights = flights.pivot("month", "year", "passengers")
ax = sns.heatmap(flights,cmap="Blues")
#ax = sns.heatmap(flights)
plt.title("Heatmap Flight Data")
plt.show()

# %%
import seaborn as sns
import pandas as pd
import numpy as np
# Create a dataset
df = pd.DataFrame(np.random.random((8,7)), columns=["a","b","c","d","e","f","g"])
# plot a heatmap with annotation
sns.heatmap(df, annot=True, annot_kws={"size": 12})

# %% [markdown]
# # Scatter Plot

# %%
import matplotlib.pyplot as plt
# price of 1bhk, 1.5 bhk, 2bhk, 2.5bhk, 3bhk, 4bhk x-type, y-price
x = [1,1.5,2,2.5,3,4]
y = [55,66,80,90,140,210]
plt.scatter(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('height_weight.csv')
fig, ax = plt.subplots(figsize=(10, 6))
ax.scatter(x = df['height'], y = df['female'])
plt.xlabel("Height of Female")
plt.ylabel("Weight for Female")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('marchcorona.csv')
fig, ax = plt.subplots(figsize=(10, 6))
ax.scatter(x = df['Day'], y = df['Cases'])
plt.xlabel("Day")
plt.ylabel("Cases")
plt.show()

# %% [markdown]
# # Box Plot

# %%
import numpy as np 
import matplotlib.pyplot as plt
sales=np.array([6,7,13,17,20,25,39,41,43,49,51,62])
fig = plt.figure(figsize =(10, 7))
plt.boxplot(sales)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from IPython import get_ipython
get_ipython().run_line_magic('matplotlib', 'inline')
df = pd.read_csv("bank.csv")
df.boxplot(by ='Account_Type',grid='True',column =['Balance'])  #color='red'
# Out:
# C:\Users\Saanya\Anaconda3\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# C:\Users\Saanya\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# # Assignment

# %%
#1.a) Use bank.csv file. Plot Sr.No.(SL) against balance. Change dot
#    to some other character e.g. *
#  b) Change size of all the dots to some specific one e.g. 300/400/500.

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('bank.csv')
fig, ax = plt.subplots(figsize=(10, 6))
ax.scatter(x = df['SL'], y = df['Balance'], marker='*')
plt.xlabel("SL")
plt.ylabel("Balance")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('bank.csv')
fig, ax = plt.subplots(figsize=(10, 6))
ax.scatter(x = df['SL'], y = df['Balance'], marker='*', s=300)
plt.xlabel("SL")
plt.ylabel("Balance")
plt.show()

# %%
#2. a) Read diamonds.csv file, plot a scatter chart based on caret 
#    and depth.
#   b) Plot a scatter chart based on caret and depth.
#      Use different colors for different cut.

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('diamonds.csv')
fig, ax = plt.subplots(figsize=(10, 6))
ax.scatter(x = df['carat'], y = df['depth'])
plt.xlabel("Carat")
plt.ylabel("Depth")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv ('diamonds.csv')
fig, ax = plt.subplots(figsize=(10, 6))
sns.scatterplot(x='carat', y='depth', data=df, hue='cut')
plt.xlabel("Carat")
plt.ylabel("Depth")
plt.show()

# %%
#3. Use the following arrays and plot a scatter chart. 
#    X axis= discount
#    Y axis= salesInRs
#    a) Size of the dot should be 10 times the discount given 
#    for salesInRs.
#    discount= np.array([30,20,10,40,50])
#    saleInRs=np.array([40000,45000,48000,50000,100000])
#    b) Change the dots to red color stars.
#    c) Make the edge color as yellow

# %%
import matplotlib.pyplot as plt
import numpy as np
discount=np.array([15,50,35,10,30])
sale=np.array([100000,300000,200000,700000,450000])
plt.scatter(x=discount, y=sale, s=discount*10)
plt.xlabel("Discount")
plt.ylabel("Sale")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
discount=np.array([15,50,35,10,30])
sale=np.array([100000,300000,200000,700000,450000])
plt.scatter(x=discount, y=sale, s=discount*10, c='red', marker='*')
plt.xlabel("Discount")
plt.ylabel("Sale")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
discount=np.array([15,50,35,10,30])
sale=np.array([100000,300000,200000,700000,450000])
plt.scatter(x=discount, y=sale, s=discount*10, c='red', marker='*', edgecolor='yellow')
plt.xlabel("Discount")
plt.ylabel("Sale")
plt.show()

# %% [markdown]
# # Graphs

# %%
graph = { "a" : ["b","c"],
          "b" : ["a", "d"],
          "c" : ["a", "d"],
          "d" : ["e"],
          "e" : ["d"]
         }
# Print the graph        
print(graph)
# Out:
# {'a': ['b', 'c'], 'b': ['a', 'd'], 'c': ['a', 'd'], 'd': ['e'], 'e': ['d']}

# %%
graph = { "5" : [3, 7],
          "3" : [2, 4],
          "7" : [8],
          "2" : [],
          "4" : [8],
          "8" : []
         }
# Print the graph        
print(graph)
# Out:
# {'5': [3, 7], '3': [2, 4], '7': [8], '2': [], '4': [8], '8': []}

# %%
graph = { "A" : ["B"],
          "B" : ["A", "C", "D"],
          "C" : ["B", "D", "E"],
          "D" : ["B", "C", "E"],
          "E" : ["C", "D"]
         }
# Print the graph        
print(graph)
# Out:
# {'A': ['B'], 'B': ['A', 'C', 'D'], 'C': ['B', 'D', 'E'], 'D': ['B', 'C', 'E'], 'E': ['C', 'D']}

# %%
graph = { 1 : [0],
          0 : [2, 3],
          2 : [1],
          3 : [4],
          4 : [0]
         }
# Print the graph        
print(graph)
# Out:
# {1: [0], 0: [2, 3], 2: [1], 3: [4], 4: [0]}

# %% [markdown]
# # DFS

# %%
graph = { 5 : [3, 7],
          3 : [2, 4],
          7 : [8],
          2 : [],
          4 : [8],
          8 : []
         }
# Print the graph        
# print(graph)

visited = set()

def dfs(visited, graph, node):
    if node not in visited:
        print(node, end=" ")
        visited.add(node)
        for neighbour in graph[node]:
            dfs(visited, graph, neighbour)
            
            
print("Following is depth first search")
dfs(visited, graph, 5)
# Out:
# Following is depth first search
# 5 3 2 4 8 7

# %%
graph = { 5 : [3, 7],
          3 : [2, 4],
          7 : [8],
          2 : [],
          4 : [8],
          8 : []
         }
# Print the graph        
# print(graph)

visited = set()

def dfs(visited, graph, node):
    if node not in visited:
        print(node, end=" ")
        visited.add(node)
        for neighbour in graph[node]:
            dfs(visited, graph, neighbour)
            
            
print("Following is depth first search")
dfs(visited, graph, list(graph.keys())[0])
# Out:
# Following is depth first search
# 5 3 2 4 8 7

# %% [markdown]
# # BFS

# %%
graph = {"a" : ["b", "c"],
        "b" : ["a", "d"],
        "d" : ["c", "e"],
        "c" : ["a", "d"],
        "e" : ["d"]
        }

visited = set()
queue = set()

def bfs(visited, graph, node):
    visited.add(node)
    queue.add(node)
    
    while queue:
        s = queue.pop()
        print(s, end=" ")
        
        for neighbour in graph[s]:
            if neighbour not in visited:
                visited.add(neighbour)
                queue.add(neighbour)
                
# Print the graph
# print(graph)

bfs(visited, graph, "a")
# Out:
# a b c d e

# %% [markdown]
# # Cartopy

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())
# make the map global rather than have it zoom in to 
# the extents of any plotted data
ax.set_extent((60, 150, 55, -25))
ax.stock_img()
ax.coastlines()
ax.tissot(facecolor='purple', alpha=0.8)
plt.show()
# Out:
# C:\Users\Saanya\Anaconda3\lib\site-packages\cartopy\mpl\geoaxes.py:762: UserWarning: Approximating coordinate system <cartopy._crs.Geodetic object at 0x000001E043D266D0> with the PlateCarree projection.
#   'PlateCarree projection.'.format(crs))

# %%
import os
import matplotlib.pyplot as plt
from netCDF4 import Dataset as netcdf_dataset
import numpy as np

from cartopy import config
import cartopy.crs as ccrs


# get the path of the file. It can be found in the repo data directory.
fname = os.path.join(config["repo_data_dir"],
                     'netcdf', 'HadISST1_SST_update.nc'
                     )

dataset = netcdf_dataset(fname)
sst = dataset.variables['sst'][0, :, :]
lats = dataset.variables['lat'][:]
lons = dataset.variables['lon'][:]

ax = plt.axes(projection=ccrs.PlateCarree())

plt.contourf(lons, lats, sst, 60,
             transform=ccrs.PlateCarree())

ax.coastlines()

plt.show()

# %% [markdown]
# # 3D Charts

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
x = np.linspace(-4*np.pi, 4*np.pi, 4)
y = np.linspace(-4*np.pi, 4*np.pi, 4)
z = x**2 + y**2
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(x, y, z)
plt.show()
